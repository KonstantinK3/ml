# %% [markdown]
# ## Mini Project # 1 - Live Sketch Using Webcam

# %%
import cv2
import numpy as np

# Our sketch generating function
def sketch(image):
    # Convert image to grayscale
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Clean up image using Guassian Blur
    img_gray_blur = cv2.GaussianBlur(img_gray, (5,5), 0)
    
    # Extract edges
    canny_edges = cv2.Canny(img_gray_blur, 10, 70)
    
    # Do an invert binarize the image 
    ret, mask = cv2.threshold(canny_edges, 70, 255, cv2.THRESH_BINARY_INV)
    return mask


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live Sketcher', sketch(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-546286b1145c> in <module>()
#      25 while True:
#      26     ret, frame = cap.read()
# ---> 27     cv2.imshow('Our Live Sketcher', sketch(frame))
#      28     if cv2.waitKey(1) == 13: #13 is the Enter Key
#      29         break
#
# <ipython-input-4-546286b1145c> in sketch(image)
#       5 def sketch(image):
#       6     # Convert image to grayscale
# ----> 7     img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       8
#       9     # Clean up image using Guassian Blur
#
# error: C:\bld\opencv_1510966172919\work\opencv-3.3.0\modules\imgproc\src\color.cpp:10638: error: (-215) scn == 3 || scn == 4 in function cv::cvtColor

# %% [markdown]
# my proj

# %%
import cv2
import numpy as np

# Our sketch generating function
def sketch(image):

    # Convert image to grayscale
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Clean up image using Guassian Blur
    img_gray_blur = cv2.GaussianBlur(img_gray, (5,5), 0)
    
    # Extract edges
    canny_edges = cv2.Canny(img_gray_blur, 10, 70)
    
    # Do an invert binarize the image 
    ret, mask = cv2.threshold(canny_edges, 70, 255, cv2.THRESH_BINARY_INV)
    return mask


# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live Sketcher', sketch(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# corners

# %%
import cv2
import numpy as np

# Our sketch generating function
def sketch(image):
    
    # Grayscale
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # We specific the top 50 corners
    corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 150)

    for corner in corners:
        x, y = corner[0]
        x = int(x)
        y = int(y)
        cv2.rectangle(image,(x-10,y-10),(x+10,y+10),(0,255,0), 2)

    return image

# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live Sketcher', sketch(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-978b9d5fc7b4> in <module>()
#      25
#      26 while True:
# ---> 27     ret, frame = cap.read()
#      28     cv2.imshow('Our Live Sketcher', sketch(frame))
#      29     if cv2.waitKey(1) == 13: #13 is the Enter Key
#
# KeyboardInterrupt:

# %% [markdown]
# ORB

# %%
import cv2
import numpy as np

# Our sketch generating function
def sketch(image):
    
    # Grayscale
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    # Create ORB object, we can specify the number of key points we desire
    orb = cv2.ORB_create()

    # Determine key points
    keypoints = orb.detect(gray, None)

    # Obtain the descriptors
    keypoints, descriptors = orb.compute(gray, keypoints)
    print("Number of keypoints Detected: ", len(keypoints))

    # Draw rich keypoints on input image
    image = cv2.drawKeypoints(image, keypoints, outImage=image, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    return image

# Initialize webcam, cap is the object provided by VideoCapture
# It contains a boolean indicating if it was sucessful (ret)
# It also contains the images collected from the webcam (frame)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    cv2.imshow('Our Live Sketcher', sketch(frame))
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
# Release camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Number of keypoints Detected:  287
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  217
# Number of keypoints Detected:  229
# Number of keypoints Detected:  309
# Number of keypoints Detected:  255
# Number of keypoints Detected:  14
# Number of keypoints Detected:  5
# Number of keypoints Detected:  43
# Number of keypoints Detected:  111
# Number of keypoints Detected:  275
# Number of keypoints Detected:  321
# Number of keypoints Detected:  204
# Number of keypoints Detected:  297
# Number of keypoints Detected:  499
# Number of keypoints Detected:  468
# Number of keypoints Detected:  282
# Number of keypoints Detected:  471
# Number of keypoints Detected:  471
# Number of keypoints Detected:  113
# Number of keypoints Detected:  106
# Number of keypoints Detected:  110
# Number of keypoints Detected:  120
# Number of keypoints Detected:  115
# Number of keypoints Detected:  107
# Number of keypoints Detected:  47
# Number of keypoints Detected:  60
# Number of keypoints Detected:  114
# Number of keypoints Detected:  65
# Number of keypoints Detected:  65
# Number of keypoints Detected:  82
# Number of keypoints Detected:  140
# Number of keypoints Detected:  179
# Number of keypoints Detected:  158
# Number of keypoints Detected:  401
# Number of keypoints Detected:  497
# Number of keypoints Detected:  479
# Number of keypoints Detected:  221
# Number of keypoints Detected:  267
# Number of keypoints Detected:  474
# Number of keypoints Detected:  310
# Number of keypoints Detected:  216
# Number of keypoints Detected:  171
# Number of keypoints Detected:  199
# Number of keypoints Detected:  450
# Number of keypoints Detected:  385
# Number of keypoints Detected:  410
# Number of keypoints Detected:  472
# Number of keypoints Detected:  488
# Number of keypoints Detected:  458
# Number of keypoints Detected:  332
# Number of keypoints Detected:  208
# Number of keypoints Detected:  391
# Number of keypoints Detected:  265
# Number of keypoints Detected:  338
# Number of keypoints Detected:  353
# Number of keypoints Detected:  401
# Number of keypoints Detected:  496
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  495
# Number of keypoints Detected:  468
# Number of keypoints Detected:  460
# Number of keypoints Detected:  370
# Number of keypoints Detected:  251
# Number of keypoints Detected:  337
# Number of keypoints Detected:  268
# Number of keypoints Detected:  349
# Number of keypoints Detected:  451
# Number of keypoints Detected:  313
# Number of keypoints Detected:  271
# Number of keypoints Detected:  453
# Number of keypoints Detected:  264
# Number of keypoints Detected:  259
# Number of keypoints Detected:  388
# Number of keypoints Detected:  393
# Number of keypoints Detected:  410
# Number of keypoints Detected:  491
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  484
# Number of keypoints Detected:  487
# Number of keypoints Detected:  495
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  498
# Number of keypoints Detected:  488
# Number of keypoints Detected:  481
# Number of keypoints Detected:  492
# Number of keypoints Detected:  497
# Number of keypoints Detected:  494
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  499
# Number of keypoints Detected:  491
# Number of keypoints Detected:  491
# Number of keypoints Detected:  499
# Number of keypoints Detected:  481
# Number of keypoints Detected:  490
# Number of keypoints Detected:  477
# Number of keypoints Detected:  489
# Number of keypoints Detected:  488
# Number of keypoints Detected:  497
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  484
# Number of keypoints Detected:  477
# Number of keypoints Detected:  470
# Number of keypoints Detected:  476
# Number of keypoints Detected:  479
# Number of keypoints Detected:  477
# Number of keypoints Detected:  467
# Number of keypoints Detected:  477
# Number of keypoints Detected:  471
# Number of keypoints Detected:  483
# Number of keypoints Detected:  492
# Number of keypoints Detected:  484
# Number of keypoints Detected:  486
# Number of keypoints Detected:  487
# Number of keypoints Detected:  482
# Number of keypoints Detected:  482
# Number of keypoints Detected:  485
# Number of keypoints Detected:  484
# Number of keypoints Detected:  492
# Number of keypoints Detected:  482
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  485
# Number of keypoints Detected:  478
# Number of keypoints Detected:  482
# Number of keypoints Detected:  482
# Number of keypoints Detected:  483
# Number of keypoints Detected:  481
# Number of keypoints Detected:  483
# Number of keypoints Detected:  485
# Number of keypoints Detected:  483
# Number of keypoints Detected:  482
# Number of keypoints Detected:  483
# Number of keypoints Detected:  483
# Number of keypoints Detected:  482
# Number of keypoints Detected:  478
# Number of keypoints Detected:  482
# Number of keypoints Detected:  485
# Number of keypoints Detected:  484
# Number of keypoints Detected:  483
# Number of keypoints Detected:  480
# Number of keypoints Detected:  486
# Number of keypoints Detected:  485
# Number of keypoints Detected:  490
# Number of keypoints Detected:  492
# Number of keypoints Detected:  491
# Number of keypoints Detected:  487
# Number of keypoints Detected:  488
# Number of keypoints Detected:  489
# Number of keypoints Detected:  495
# Number of keypoints Detected:  491
# Number of keypoints Detected:  492
# Number of keypoints Detected:  487
# Number of keypoints Detected:  484
# Number of keypoints Detected:  482
# Number of keypoints Detected:  487
# Number of keypoints Detected:  481
# Number of keypoints Detected:  488
# Number of keypoints Detected:  485
# Number of keypoints Detected:  491
# Number of keypoints Detected:  479
# Number of keypoints Detected:  484
# Number of keypoints Detected:  457
# Number of keypoints Detected:  448
# Number of keypoints Detected:  349
# Number of keypoints Detected:  485
# Number of keypoints Detected:  474
# Number of keypoints Detected:  476
# Number of keypoints Detected:  483
# Number of keypoints Detected:  499
# Number of keypoints Detected:  491
# Number of keypoints Detected:  489
# Number of keypoints Detected:  493
# Number of keypoints Detected:  479
# Number of keypoints Detected:  387
# Number of keypoints Detected:  414
# Number of keypoints Detected:  415
# Number of keypoints Detected:  488
# Number of keypoints Detected:  479
# Number of keypoints Detected:  482
# Number of keypoints Detected:  407
# Number of keypoints Detected:  464
# Number of keypoints Detected:  467
# Number of keypoints Detected:  414
# Number of keypoints Detected:  467
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  497
# Number of keypoints Detected:  473
# Number of keypoints Detected:  496
# Number of keypoints Detected:  490
# Number of keypoints Detected:  473
# Number of keypoints Detected:  490
# Number of keypoints Detected:  498
# Number of keypoints Detected:  495
# Number of keypoints Detected:  478
# Number of keypoints Detected:  465
# Number of keypoints Detected:  478
# Number of keypoints Detected:  485
# Number of keypoints Detected:  478
# Number of keypoints Detected:  468
# Number of keypoints Detected:  464
# Number of keypoints Detected:  488
# Number of keypoints Detected:  485
# Number of keypoints Detected:  487
# Number of keypoints Detected:  481
# Number of keypoints Detected:  479
# Number of keypoints Detected:  481
# Number of keypoints Detected:  486
# Number of keypoints Detected:  487
# Number of keypoints Detected:  494
# Number of keypoints Detected:  493
# Number of keypoints Detected:  494
# Number of keypoints Detected:  497
# Number of keypoints Detected:  497
# Number of keypoints Detected:  487
# Number of keypoints Detected:  492
# Number of keypoints Detected:  497
# Number of keypoints Detected:  494
# Number of keypoints Detected:  493
# Number of keypoints Detected:  499
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  492
# Number of keypoints Detected:  495
# Number of keypoints Detected:  491
# Number of keypoints Detected:  491
# Number of keypoints Detected:  489
# Number of keypoints Detected:  495
# Number of keypoints Detected:  493
# Number of keypoints Detected:  492
# Number of keypoints Detected:  486
# Number of keypoints Detected:  495
# Number of keypoints Detected:  495
# Number of keypoints Detected:  490
# Number of keypoints Detected:  493
# Number of keypoints Detected:  493
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  493
# Number of keypoints Detected:  495
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  499
# Number of keypoints Detected:  499
# Number of keypoints Detected:  498
# Number of keypoints Detected:  496
# Number of keypoints Detected:  496
# Number of keypoints Detected:  490
# Number of keypoints Detected:  492
# Number of keypoints Detected:  495
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  494
# Number of keypoints Detected:  492
# Number of keypoints Detected:  495
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  492
# Number of keypoints Detected:  494
# Number of keypoints Detected:  495
# Number of keypoints Detected:  496
# Number of keypoints Detected:  494
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  492
# Number of keypoints Detected:  496
# Number of keypoints Detected:  498
# Number of keypoints Detected:  494
# Number of keypoints Detected:  490
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  491
# Number of keypoints Detected:  493
# Number of keypoints Detected:  490
# Number of keypoints Detected:  492
# Number of keypoints Detected:  492
# Number of keypoints Detected:  496
# Number of keypoints Detected:  487
# Number of keypoints Detected:  488
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  486
# Number of keypoints Detected:  489
# Number of keypoints Detected:  488
# Number of keypoints Detected:  484
# Number of keypoints Detected:  481
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  495
# Number of keypoints Detected:  491
# Number of keypoints Detected:  493
# Number of keypoints Detected:  494
# Number of keypoints Detected:  493
# Number of keypoints Detected:  492
# Number of keypoints Detected:  487
# Number of keypoints Detected:  494
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  495
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  490
# Number of keypoints Detected:  494
# Number of keypoints Detected:  491
# Number of keypoints Detected:  497
# Number of keypoints Detected:  493
# Number of keypoints Detected:  493
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  492
# Number of keypoints Detected:  491
# Number of keypoints Detected:  488
# Number of keypoints Detected:  494
# Number of keypoints Detected:  492
# Number of keypoints Detected:  489
# Number of keypoints Detected:  493
# Number of keypoints Detected:  492
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  496
# Number of keypoints Detected:  496
# Number of keypoints Detected:  492
# Number of keypoints Detected:  494
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  498
# Number of keypoints Detected:  494
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  496
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  496
# Number of keypoints Detected:  494
# Number of keypoints Detected:  495
# Number of keypoints Detected:  493
# Number of keypoints Detected:  491
# Number of keypoints Detected:  491
# Number of keypoints Detected:  494
# Number of keypoints Detected:  494
# Number of keypoints Detected:  490
# Number of keypoints Detected:  491
# Number of keypoints Detected:  492
# Number of keypoints Detected:  494
# Number of keypoints Detected:  492
# Number of keypoints Detected:  492
# Number of keypoints Detected:  493
# Number of keypoints Detected:  490
# Number of keypoints Detected:  489
# Number of keypoints Detected:  485
# Number of keypoints Detected:  490
# Number of keypoints Detected:  491
# Number of keypoints Detected:  488
# Number of keypoints Detected:  487
# Number of keypoints Detected:  481
# Number of keypoints Detected:  488
# Number of keypoints Detected:  488
# Number of keypoints Detected:  492
# Number of keypoints Detected:  480
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  487
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  483
# Number of keypoints Detected:  491
# Number of keypoints Detected:  491
# Number of keypoints Detected:  484
# Number of keypoints Detected:  488
# Number of keypoints Detected:  486
# Number of keypoints Detected:  482
# Number of keypoints Detected:  485
# Number of keypoints Detected:  486
# Number of keypoints Detected:  485
# Number of keypoints Detected:  489
# Number of keypoints Detected:  490
# Number of keypoints Detected:  492
# Number of keypoints Detected:  493
# Number of keypoints Detected:  490
# Number of keypoints Detected:  490
# Number of keypoints Detected:  494
# Number of keypoints Detected:  495
# Number of keypoints Detected:  489
# Number of keypoints Detected:  484
# Number of keypoints Detected:  481
# Number of keypoints Detected:  480
# Number of keypoints Detected:  489
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  488
# Number of keypoints Detected:  490
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  485
# Number of keypoints Detected:  485
# Number of keypoints Detected:  488
# Number of keypoints Detected:  482
# Number of keypoints Detected:  483
# Number of keypoints Detected:  488
# Number of keypoints Detected:  488
# Number of keypoints Detected:  487
# Number of keypoints Detected:  494
# Number of keypoints Detected:  493
# Number of keypoints Detected:  492
# Number of keypoints Detected:  492
# Number of keypoints Detected:  493
# Number of keypoints Detected:  492
# Number of keypoints Detected:  491
# Number of keypoints Detected:  488
# Number of keypoints Detected:  483
# Number of keypoints Detected:  492
# Number of keypoints Detected:  485
# Number of keypoints Detected:  494
# Number of keypoints Detected:  495
# Number of keypoints Detected:  491
# Number of keypoints Detected:  489
# Number of keypoints Detected:  490
# Number of keypoints Detected:  493
# Number of keypoints Detected:  495
# Number of keypoints Detected:  490
# Number of keypoints Detected:  486
# Number of keypoints Detected:  493
# Number of keypoints Detected:  490
# Number of keypoints Detected:  488
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  489
# Number of keypoints Detected:  486
# Number of keypoints Detected:  489
# Number of keypoints Detected:  487
# Number of keypoints Detected:  488
# Number of keypoints Detected:  490
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  488
# Number of keypoints Detected:  493
# Number of keypoints Detected:  493
# Number of keypoints Detected:  494
# Number of keypoints Detected:  490
# Number of keypoints Detected:  491
# Number of keypoints Detected:  492
# Number of keypoints Detected:  492
# Number of keypoints Detected:  493
# Number of keypoints Detected:  488
# Number of keypoints Detected:  491
# Number of keypoints Detected:  487
# Number of keypoints Detected:  491
# Number of keypoints Detected:  491
# Number of keypoints Detected:  491
# Number of keypoints Detected:  486
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  486
# Number of keypoints Detected:  490
# Number of keypoints Detected:  490
# Number of keypoints Detected:  490
# Number of keypoints Detected:  491
# Number of keypoints Detected:  489
# Number of keypoints Detected:  495
# Number of keypoints Detected:  490
# Number of keypoints Detected:  492
# Number of keypoints Detected:  494
# Number of keypoints Detected:  491
# Number of keypoints Detected:  493
# Number of keypoints Detected:  491
# Number of keypoints Detected:  492
# Number of keypoints Detected:  489
# Number of keypoints Detected:  488
# Number of keypoints Detected:  488
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  492
# Number of keypoints Detected:  490
# Number of keypoints Detected:  493
# Number of keypoints Detected:  491
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  487
# Number of keypoints Detected:  490
# Number of keypoints Detected:  488
# Number of keypoints Detected:  492
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  489
# Number of keypoints Detected:  490
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  491
# Number of keypoints Detected:  488
# Number of keypoints Detected:  492
# Number of keypoints Detected:  489
# Number of keypoints Detected:  488
# Number of keypoints Detected:  489
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  488
# Number of keypoints Detected:  488
# Number of keypoints Detected:  487
# Number of keypoints Detected:  491
# Number of keypoints Detected:  490
# Number of keypoints Detected:  487
# Number of keypoints Detected:  492
# Number of keypoints Detected:  492
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  489
# Number of keypoints Detected:  485
# Number of keypoints Detected:  484
# Number of keypoints Detected:  487
# Number of keypoints Detected:  485
# Number of keypoints Detected:  486
# Number of keypoints Detected:  482
# Number of keypoints Detected:  484
# Number of keypoints Detected:  486
# Number of keypoints Detected:  488
# Number of keypoints Detected:  486
# Number of keypoints Detected:  484
# Number of keypoints Detected:  481
# Number of keypoints Detected:  478
# Number of keypoints Detected:  476
# Number of keypoints Detected:  478
# Number of keypoints Detected:  483
# Number of keypoints Detected:  484
# Number of keypoints Detected:  481
# Number of keypoints Detected:  479
# Number of keypoints Detected:  476
# Number of keypoints Detected:  484
# Number of keypoints Detected:  487
# Number of keypoints Detected:  489
# Number of keypoints Detected:  486
# Number of keypoints Detected:  489
# Number of keypoints Detected:  480
# Number of keypoints Detected:  487
# Number of keypoints Detected:  494
# Number of keypoints Detected:  497
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  494
# Number of keypoints Detected:  493
# Number of keypoints Detected:  482
# Number of keypoints Detected:  487
# Number of keypoints Detected:  480
# Number of keypoints Detected:  478
# Number of keypoints Detected:  478
# Number of keypoints Detected:  477
# Number of keypoints Detected:  471
# Number of keypoints Detected:  481
# Number of keypoints Detected:  478
# Number of keypoints Detected:  476
# Number of keypoints Detected:  476
# Number of keypoints Detected:  488
# Number of keypoints Detected:  485
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  495
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  494
# Number of keypoints Detected:  492
# Number of keypoints Detected:  488
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  498
# Number of keypoints Detected:  496
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  496
# Number of keypoints Detected:  499
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  496
# Number of keypoints Detected:  499
# Number of keypoints Detected:  496
# Number of keypoints Detected:  492
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  495
# Number of keypoints Detected:  495
# Number of keypoints Detected:  500
# Number of keypoints Detected:  494
# Number of keypoints Detected:  497
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  493
# Number of keypoints Detected:  496
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  497
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  499
# Number of keypoints Detected:  495
# Number of keypoints Detected:  495
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  496
# Number of keypoints Detected:  500
# Number of keypoints Detected:  496
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  496
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  496
# Number of keypoints Detected:  495
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  493
# Number of keypoints Detected:  493
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  499
# Number of keypoints Detected:  496
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  500
# Number of keypoints Detected:  493
# Number of keypoints Detected:  497
# Number of keypoints Detected:  497
# Number of keypoints Detected:  494
# Number of keypoints Detected:  492
# Number of keypoints Detected:  495
# Number of keypoints Detected:  494
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  497
# Number of keypoints Detected:  499
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  500
# Number of keypoints Detected:  498
# Number of keypoints Detected:  497
# Number of keypoints Detected:  496
# Number of keypoints Detected:  486
# Number of keypoints Detected:  482
# Number of keypoints Detected:  489
# Number of keypoints Detected:  459
# Number of keypoints Detected:  409
# Number of keypoints Detected:  338
# Number of keypoints Detected:  322
# Number of keypoints Detected:  257
# Number of keypoints Detected:  187
# Number of keypoints Detected:  106
# Number of keypoints Detected:  155
# Number of keypoints Detected:  152
# Number of keypoints Detected:  96
# Number of keypoints Detected:  54
# Number of keypoints Detected:  10
# Number of keypoints Detected:  17
# Number of keypoints Detected:  18
# Number of keypoints Detected:  17
# Number of keypoints Detected:  5
# Number of keypoints Detected:  0
# Number of keypoints Detected:  2
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  0
# Number of keypoints Detected:  2
# Number of keypoints Detected:  1
# Number of keypoints Detected:  4
# Number of keypoints Detected:  4
# Number of keypoints Detected:  8
# Number of keypoints Detected:  11
# Number of keypoints Detected:  11
# Number of keypoints Detected:  10
# Number of keypoints Detected:  6
# Number of keypoints Detected:  6
# Number of keypoints Detected:  7
# Number of keypoints Detected:  5
# Number of keypoints Detected:  6
# Number of keypoints Detected:  7
# Number of keypoints Detected:  7
# Number of keypoints Detected:  8
# Number of keypoints Detected:  12
# Number of keypoints Detected:  11
# Number of keypoints Detected:  9
# Number of keypoints Detected:  13
# Number of keypoints Detected:  11
# Number of keypoints Detected:  12
# Number of keypoints Detected:  8
# Number of keypoints Detected:  12
# Number of keypoints Detected:  14
# Number of keypoints Detected:  11
# Number of keypoints Detected:  11
# Number of keypoints Detected:  12
# Number of keypoints Detected:  12
# Number of keypoints Detected:  11
# Number of keypoints Detected:  12
# Number of keypoints Detected:  8
# Number of keypoints Detected:  14
# Number of keypoints Detected:  13
# Number of keypoints Detected:  11
# Number of keypoints Detected:  14
# Number of keypoints Detected:  10
# Number of keypoints Detected:  9
# Number of keypoints Detected:  12
# Number of keypoints Detected:  9
# Number of keypoints Detected:  11
# Number of keypoints Detected:  10
# Number of keypoints Detected:  13
# Number of keypoints Detected:  13
# Number of keypoints Detected:  10
# Number of keypoints Detected:  15
# Number of keypoints Detected:  18
# Number of keypoints Detected:  14
# Number of keypoints Detected:  13
# Number of keypoints Detected:  13
# Number of keypoints Detected:  17
# Number of keypoints Detected:  12
# Number of keypoints Detected:  15
# Number of keypoints Detected:  14
# Number of keypoints Detected:  13
# Number of keypoints Detected:  16
# Number of keypoints Detected:  16
# Number of keypoints Detected:  16
# Number of keypoints Detected:  14
# Number of keypoints Detected:  14
# Number of keypoints Detected:  13
# Number of keypoints Detected:  12
# Number of keypoints Detected:  13
# Number of keypoints Detected:  12
# Number of keypoints Detected:  12
# Number of keypoints Detected:  12
# Number of keypoints Detected:  16

# %% [markdown]
# Mini-project ORB

# %%
import cv2
import numpy as np


def ORB_detector(new_image, image_template):
    # Function that compares input image to template
    # It then returns the number of ORB matches between them
    
    image1 = cv2.cvtColor(new_image, cv2.COLOR_BGR2GRAY)

    # Create ORB detector with 1000 keypoints with a scaling pyramid factor of 1.2
    orb = cv2.ORB_create(1000, 1.2)

    # Detect keypoints of original image
    (kp1, des1) = orb.detectAndCompute(image1, None)

    # Detect keypoints of rotated image
    (kp2, des2) = orb.detectAndCompute(image_template, None)

    # Create matcher 
    # Note we're no longer using Flannbased matching
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    # Do matching
    matches = bf.match(des1,des2)

    # Sort the matches based on distance.  Least distance
    # is better
    matches = sorted(matches, key=lambda val: val.distance)

    return len(matches)

cap = cv2.VideoCapture(0)

# Load our image template, this is our reference image
image_template = cv2.imread('images/box_in_scene.png', 0) 
# image_template = cv2.imread('images/kitkat.jpg', 0) 

while True:

    # Get webcam images
    ret, frame = cap.read()
    
    # Get height and width of webcam frame
    height, width = frame.shape[:2]

    # Define ROI Box Dimensions (Note some of these things should be outside the loop)
    top_left_x = int(width / 3)
    top_left_y = int((height / 2) + (height / 4))
    bottom_right_x = int((width / 3) * 2)
    bottom_right_y = int((height / 2) - (height / 4))
    
    # Draw rectangular window for our region of interest
    cv2.rectangle(frame, (top_left_x,top_left_y), (bottom_right_x,bottom_right_y), 255, 3)
    
    # Crop window of observation we defined above
    cropped = frame[bottom_right_y:top_left_y , top_left_x:bottom_right_x]

    # Flip frame orientation horizontally
    frame = cv2.flip(frame,1)
    
    # Get number of ORB matches 
    matches = ORB_detector(cropped, image_template)
    
    # Display status string showing the current no. of matches 
    output_string = "Matches = " + str(matches)
    cv2.putText(frame, output_string, (50,450), cv2.FONT_HERSHEY_COMPLEX, 2, (250,0,150), 2)
    
    # Our threshold to indicate object deteciton
    # For new images or lightening conditions you may need to experiment a bit 
    # Note: The ORB detector to get the top 1000 matches, 350 is essentially a min 35% match
    threshold = 350
    
    # If matches exceed our threshold then object has been detected
    if matches > threshold:
        cv2.rectangle(frame, (top_left_x,top_left_y), (bottom_right_x,bottom_right_y), (0,255,0), 3)
        cv2.putText(frame,'Object Found',(50,50), cv2.FONT_HERSHEY_COMPLEX, 2 ,(0,255,0), 2)
    
    cv2.imshow('Object Detector using ORB', frame)
    
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f662e99841ef> in <module>()
#      40
#      41     # Get webcam images
# ---> 42     ret, frame = cap.read()
#      43
#      44     # Get height and width of webcam frame
#
# KeyboardInterrupt:
